# %%
import pandas

# %%
df = pandas.read_csv("C:\\Users\\atif.shafiq\\Downloads\\Recovery Hospital Codes backup\\Vitros4600_RGH.csv")
df
# Out:
#                                                                          Vitros4600_RGH.switch  \
# HostCode HIS Code Display Name            Send Order Check Specimen Type                Factor
# 300      10782    2HPP                    true             6                               1.0
#          10508    Glucose FBS             true             6                               1.0
#          10819    Glucose RBS             false            6                               1.0
#          10946    Glucose urine           false            3                               1.0
#          11347    Glucose CSF             false            2                               1.0
# 301      10903    Total protein           true             NaN                             1.0
# 302      10938    Uric Acid               true             NaN                             1.0
# 303      10209    Albumin                 true             NaN                             1.0
# ...
